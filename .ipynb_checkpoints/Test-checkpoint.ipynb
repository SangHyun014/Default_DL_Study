# %%
# !pip list
# Out:
# Package              Version
# -------------------- ---------
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# asttokens            2.0.5
# attrs                21.4.0
# backcall             0.2.0
# beautifulsoup4       4.11.1
# bleach               4.1.0
# certifi              2022.6.15
# cffi                 1.15.0
# colorama             0.4.4
# cycler               0.11.0
# debugpy              1.5.1
# decorator            5.1.1
# defusedxml           0.7.1
# entrypoints          0.4
# executing            0.8.3
# fastjsonschema       2.15.1
# fonttools            4.25.0
# ipykernel            6.9.1
# ipython              8.3.0
# ipython-genutils     0.2.0
# jedi                 0.18.1
# Jinja2               3.0.3
# jsonschema           4.4.0
# jupyter-client       7.2.2
# jupyter-core         4.10.0
# jupyterlab-pygments  0.1.2
# jupyterthemes        0.20.0
# kiwisolver           1.4.2
# lesscpy              0.15.0
# MarkupSafe           2.1.1
# ...

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !conda update numpy
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
# !pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=ca22d0220b0b856b8da05a71d06389eb51c875cc0e46fc3665c564e3303cbd8c
#   Stored in directory: c:\users\kwarkmc\appdata\local\pip\cache\wheels\e4\7b\98\b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# ...

# %%
# !pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4848 sha256=6bb3a55a332bed3c9dfa60cd27b576eb482c0b06957554541dd170cf1cb3fecc
#   Stored in directory: c:\users\kwarkmc\appdata\local\pip\cache\wheels\b6\0d\90\0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built termcolor
# ...

# %%
# !pip install tensorflow_addons
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !conda list
# Out:
# # packages in environment at C:\ProgramData\Anaconda3\envs\RestApp:
# #
# # Name                    Version                   Build  Channel
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0           py39h2bbff1b_0
# asttokens                 2.0.5              pyhd3eb1b0_0
# attrs                     21.4.0             pyhd3eb1b0_0
# backcall                  0.2.0              pyhd3eb1b0_0
# beautifulsoup4            4.11.1           py39haa95532_0
# blas                      1.0                         mkl
# bleach                    4.1.0              pyhd3eb1b0_0
# brotli                    1.0.9                ha925a31_2
# ca-certificates           2022.4.26            haa95532_0
# certifi                   2022.6.15        py39haa95532_0
# cffi                      1.15.0           py39h2bbff1b_1
# colorama                  0.4.4              pyhd3eb1b0_0
# cycler                    0.11.0             pyhd3eb1b0_0
# ...

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t onedork -f bitstream -T -N -fs 10 -nf opensans -nfs 9

# %%
# !conda list
# Out:
# # packages in environment at C:\ProgramData\Anaconda3\envs\RestApp:
# #
# # Name                    Version                   Build  Channel
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0           py39h2bbff1b_0
# asttokens                 2.0.5              pyhd3eb1b0_0
# attrs                     21.4.0             pyhd3eb1b0_0
# backcall                  0.2.0              pyhd3eb1b0_0
# beautifulsoup4            4.11.1           py39haa95532_0
# blas                      1.0                         mkl
# bleach                    4.1.0              pyhd3eb1b0_0
# brotli                    1.0.9                ha925a31_2
# ca-certificates           2022.4.26            haa95532_0
# certifi                   2022.6.15        py39haa95532_0
# cffi                      1.15.0           py39h2bbff1b_1
# colorama                  0.4.4              pyhd3eb1b0_0
# cycler                    0.11.0             pyhd3eb1b0_0
# ...

# %%
# !pip install pytorch
# Out:
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\ProgramData\Anaconda3\envs\RestApp\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\kwarkmc\\AppData\\Local\\Temp\\pip-install-domtry55\\pytorch_f20ae06153fb4db095fb9086690c875e\\setup.py'"'"'; __file__='"'"'C:\\Users\\kwarkmc\\AppData\\Local\\Temp\\pip-install-domtry55\\pytorch_f20ae06153fb4db095fb9086690c875e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\kwarkmc\AppData\Local\Temp\pip-wheel-9wjus71a'
#        cwd: C:\Users\kwarkmc\AppData\Local\Temp\pip-install-domtry55\pytorch_f20ae06153fb4db095fb9086690c875e\
#   Complete output (5 lines):
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
# ...

# %%
# !conda install pytorch
# Out:
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# ...
# Examining pickleshare:  99%|#########9| 118/119 [00:47<00:00,  9.36it/s]
#
#
# Determining conflicts:   0%|          | 0/119 [00:00<?, ?it/s]
# Examining conflict for asttokens stack_data ipython:   0%|          | 0/119 [00:00<?, ?it/s]
# ...

# %%
# !conda list
# Out:
# # packages in environment at C:\ProgramData\Anaconda3\envs\RestApp:
# #
# # Name                    Version                   Build  Channel
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0           py39h2bbff1b_0
# asttokens                 2.0.5              pyhd3eb1b0_0
# attrs                     21.4.0             pyhd3eb1b0_0
# backcall                  0.2.0              pyhd3eb1b0_0
# beautifulsoup4            4.11.1           py39haa95532_0
# blas                      1.0                         mkl
# bleach                    4.1.0              pyhd3eb1b0_0
# brotli                    1.0.9                ha925a31_2
# ca-certificates           2022.4.26            haa95532_0
# certifi                   2022.6.15        py39haa95532_0
# cffi                      1.15.0           py39h2bbff1b_1
# colorama                  0.4.4              pyhd3eb1b0_0
# cycler                    0.11.0             pyhd3eb1b0_0
# ...

# %%
# !pip install pytorch-directml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement pytorch-directml (from versions: none)
# ERROR: No matching distribution found for pytorch-directml
